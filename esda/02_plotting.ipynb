# %%
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## X,Y Plots

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)
ylabel('I')
xlabel('d')

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)
ylabel(r'$I= \exp(-d)$')
xlabel('d')

# %%
type(d)
d[0:10]
# Out:
# array([ 1.        ,  1.04522613,  1.09045226,  1.13567839,  1.18090452,
#         1.22613065,  1.27135678,  1.31658291,  1.36180905,  1.40703518])

# %%
d = np.linspace(1,10,200)
I = d**(-2)
plot(d,I)
ylabel(r'$I= 1 / d^2$')
xlabel('d')

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2)
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex)
xlabel('d')

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2, label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, label = r'$I = \exp(-d)$')
xlabel('d')
legend()

# %%
legend?

# %%
legen
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-fc4fac902274> in <module>()
# ----> 1 legen
#
# NameError: name 'legen' is not defined

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2, 'r-', label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, 'g--',label = r'$I = \exp(-d)$')
xlabel('d')
legend()

# %%
d = np.linspace(1,10,200)
Iid = d**(-1)
plot(d,Iid, 'b-.', label = r'$I = d^{-1}$')
Iid2 = d**(-2)
plot(d,Iid2, 'r-', label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, 'g--',label = r'$I = \exp(-d)$')
xlabel('d')
legend()
title('Distance Decay')

# %% [markdown]
# ## Scatter Plot

# %%
x = np.arange(100)
y = 0.5 + np.random.normal(size=(100,))
scatter(x,y)
xlabel('x')
ylabel('y')

# %%
scatter(x,y)
vlines(x.mean(),y.min(),y.max())
hlines(x.min(),x.max(),y.mean())

# %% [markdown]
# ## Distributions and Densities

# %%
import numpy as np

x = np.random.multivariate_normal([100,70],[[2.,1.7],[1.7,2.]], (50))

# %%
x
# Out:
# array([[  98.70844318,   69.30918187],
#        [  99.75326973,   71.07057506],
#        [ 102.74096215,   72.26926589],
#        [  97.57908771,   66.76791618],
#        [  98.89917001,   67.12024651],
#        [  99.17280881,   69.92120358],
#        [  99.68414399,   69.87202827],
#        [  97.38889119,   69.01782105],
#        [ 102.14640836,   70.66908091],
#        [ 100.02251185,   69.26631652],
#        [  98.78992341,   69.43589263],
#        [ 100.31080985,   70.50286698],
#        [  96.67390017,   65.76499733],
#        [  97.68268123,   68.99077843],
#        [  99.13650436,   70.78039944],
#        [ 102.30743346,   71.26299837],
#        [ 100.03984402,   70.39184903],
#        [ 100.87869394,   70.48985747],
#        [  99.03631594,   69.30106239],
#        [ 100.0510933 ,   69.71162458],
#        [  99.22007193,   69.1777817 ],
#        [ 100.79311948,   70.25651666],
#        [  98.91533789,   66.57040376],
#        [ 102.23468159,   72.11731104],
#        [ 102.16846487,   73.51826357],
#        [  97.74975456,   67.70026094],
#        [ 100.37511949,   71.07495733],
#        [  97.6615154 ,   68.60906483],
#        [ 101.79840231,   71.59654249],
#        [  99.01796778,   68.50190873],
#        [ 100.37746351,   69.87918707],
#        [  99.9700452 ,   68.94988709],
#        [  99.89540028,   68.88969004],
#        [  99.02774576,   69.05673556],
#        [  99.33257207,   69.34331347],
#        [  99.31234148,   68.54676323],
#        [  99.7346969 ,   70.55249526],
#        [  98.84293911,   69.30341953],
#        [ 100.47525336,   69.9789413 ],
#        [  99.35406098,   70.99947503],
#        [  97.01964583,   68.37250645],
#        [ 100.87542045,   71.03848732],
#        [  99.8889627 ,   70.44635239],
#        [ 101.32174763,   71.87285693],
#        [  97.42744212,   69.1858979 ],
#        [ 100.37150531,   71.27828543],
#        [  97.60913043,   68.28194788],
#        [ 100.5584879 ,   71.70549843],
#        [  96.34862814,   66.52030005],
#        [ 100.37492052,   69.96913874]])

# %%
plot(x)
# Out:
# [<matplotlib.lines.Line2D at 0x1096043d0>,
#  <matplotlib.lines.Line2D at 0x109604650>]

# %%
plot(x[:,0], x[:,1], "o")

# %%
x0h = hist(x[:,0])

# %%
x1h = hist(x[:,1])

# %%
n,bins,bars = hist(x[:,1])

y = normpdf(bins, mean(x[:,1]), std(x[:,1]))

# %%
plot(bins,y)

# %%
plot(bins,y)
hist(x[:,1])
# Out:
# (array([  2.,   3.,   1.,   5.,  13.,   8.,  10.,   5.,   2.,   1.]),
#  array([ 65.76499733,  66.54032395,  67.31565057,  68.0909772 ,
#          68.86630382,  69.64163045,  70.41695707,  71.1922837 ,
#          71.96761032,  72.74293695,  73.51826357]),
#  <a list of 10 Patch objects>)

# %%
plot(bins,y)
hist(x[:,1],normed=1)
# Out:
# (array([ 0.05159116,  0.07738674,  0.02579558,  0.1289779 ,  0.33534254,
#          0.20636464,  0.2579558 ,  0.1289779 ,  0.05159116,  0.02579558]),
#  array([ 65.76499733,  66.54032395,  67.31565057,  68.0909772 ,
#          68.86630382,  69.64163045,  70.41695707,  71.1922837 ,
#          71.96761032,  72.74293695,  73.51826357]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Saving to a file

# %%
plot(bins,y)
hist(x[:,1],normed=1)
savefig("hist.png")

# %%
# !ls *.png
# Out:
# hist.png

# %%
from scipy.stats import gaussian_kde

# %%
y = x[:,1]
density = gaussian_kde(y)

# %%
xs = np.linspace(y.min(),y.max(),30)
plot(xs, density(xs))
xlabel('y')
ylabel('f(y)')

# %%
xs = np.linspace(y.min()*.8,y.max()*1.2,30)
plot(xs, density(xs))
xlabel('y')
ylabel('f(y)')

# %% [markdown]
# There is a lot more to matplotlib. One can visit the [gallery](http://matplotlib.org/gallery.html) and pull examples in to get a sense of what is possible, and how to adapt examples for your own purposes.
#
#
# For now we move on to generating choropleth maps.
